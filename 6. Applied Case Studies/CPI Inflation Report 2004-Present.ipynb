# %% [markdown]
# # US Inflation Trends (2004 – Present)
#
# ## Consumer Price Index (CPI) vs. Core CPI Year-over-Year
#
# ### Description
#
# This notebook provides a technical visualization of U.S. inflationary trends over the past decade. It utilizes data from the Federal Reserve Economic Data (FRED) to compare:
#
# - **Headline CPI (All Urban Consumers)**
# - **Core CPI (All Items Less Food and Energy)**
#
# The analysis focuses on year-over-year percentage changes to highlight underlying inflation dynamics, separating volatile components (food and energy) from broader price movements.
#
# ---
#
# ## Objectives
#
# - Analyze long-term inflation trends from 2008 to present day
# - Compare headline vs. core inflation behaviors
# - Identify periods of inflation acceleration and deceleration
# - Provide a time-logged macroeconomic and financial analysis
#
# ---
#
# ## Data Source
#
# - Federal Reserve Economic Data (FRED)
#   - CPIAUCSL: Consumer Price Index for All Urban Consumers
#   - CPILFESL: Consumer Price Index Less Food and Energy

# %% [markdown]
# ## CPI Inflation (2006-Present)
# ### Key Events
# - 2008 Finanical Housing Crisis
# - COVID-19 Pandemic
# - Start of Iran War

# %%
# Install system dependencies
# !pip install pandas-datareader
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Import python libraries
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

start = datetime(2005, 1, 1)
end = datetime.now()
str_current_date = end.strftime("%B %d, %Y")
plot_start = start + relativedelta(years=1)

# Fetch data from FRED
df = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

# Year-over-Year percentage change
df_yoy = df.pct_change(periods=12) * 100

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df_yoy.index, df_yoy['CPIAUCSL'], label='Headline CPI (YoY %)', color='#1f77b4', linewidth=2)
plt.plot(df_yoy.index, df_yoy['CPILFESL'], label='Core CPI (YoY %)', color="#ff260e", linewidth=2)

# Critical Event Markers
# 2008 Financial Crisis -- NBER start: Dec 2007
evt_recession = pd.to_datetime('2007-12-01')
plt.axvline(x=evt_recession, color='gray', linestyle='--', linewidth=1)
plt.text(evt_recession, plt.ylim()[1]*0.9, '2008 US Recession',
         rotation=90, verticalalignment='top', fontsize=9)

# COVID-19 Pandemic -- March 2020
evt_covid = pd.to_datetime('2020-03-01')
plt.axvline(x=evt_covid, color='gray', linestyle='--', linewidth=1)
plt.text(evt_covid, plt.ylim()[1]*0.9, 'COVID-19 Global Pandemic',
         rotation=90, verticalalignment='top', fontsize=9)

# US-Israeli Joint Strikes on Iran -- Feb 2026
evt_iran = pd.to_datetime('2026-02-28')
plt.axvline(x=evt_iran, color='gray', linestyle='--', linewidth=1)
plt.text(evt_iran, plt.ylim()[1]*0.9, 'Strait of Hormuz Closes',
         rotation=90, verticalalignment='top', fontsize=9)

# Formatting
#plt.title(f'US Inflation: Headline vs. Core CPI (2004 – {end.year})\nas of {str_current_date}', fontsize=14, fontweight='bold')
plt.title(f'US Inflation: Headline vs. Core CPI ({plot_start.strftime("%B %Y")} – {end.strftime("%B %Y")})\nas of {str_current_date}', fontsize=14, fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.axhline(0, color='black', linewidth=0.8, linestyle='-')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# /var/folders/71/ng2k1j0j5zl7wss17qgbmsfr0000gn/T/ipykernel_24804/3667914873.py:17: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_yoy = df.pct_change(periods=12) * 100

# %% [markdown]
# ## CPI Inflation (June 2026-Present)
# ### Key Events
# - Presidential Inauguration of Donald J. Trump's as the 47th President of the United States of America.
# - Effective start of President Trump's global tariffs policy.
# - U.S. Congressional 43-day shutdown.
# - Iran closed the Straight of Hormuz.

# %%
# Import python libraries
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

start = datetime(2023, 6, 1)
end = datetime.now()
str_current_date = end.strftime("%B %d, %Y")
plot_start = start + relativedelta(years=1)

# Fetch data from FRED
df = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

# Year-over-Year percentage change
df_yoy = df.pct_change(periods=12) * 100
df_yoy = df_yoy[df_yoy.index >= start]

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df_yoy.index, df_yoy['CPIAUCSL'], label='Headline CPI (YoY %)', color='#1f77b4', linewidth=2)
plt.plot(df_yoy.index, df_yoy['CPILFESL'], label='Core CPI (YoY %)', color="#ff260e", linewidth=2)

# Critical Event Markers

# Inauguration of Donald J. Trump - Jan 2025
evt_term2 = pd.to_datetime('2025-01-20')
plt.axvline(x=evt_term2, color='gray', linestyle='--', linewidth=1)
plt.text(evt_term2, plt.ylim()[1]*0.9, 'Donald Trump Enters Second Presidential Term',
         rotation=90, verticalalignment='top', fontsize=9)

# President Trump Orders Global Tariffs -- April 2025
evt_lib_tariff = pd.to_datetime('2025-04-15')
plt.axvline(x=evt_lib_tariff, color='gray', linestyle='--', linewidth=1)
plt.text(evt_lib_tariff, plt.ylim()[1]*0.9, 'Trump Imposes Global Foreign Trade Policy',
         rotation=90, verticalalignment='top', fontsize=9)

# October 2025 Government Shutdown - Oct 2025
evt_shutdown = pd.to_datetime('2025-10-01')
plt.axvline(x=evt_shutdown, color='gray', linestyle='--', linewidth=1)
plt.text(evt_shutdown, plt.ylim()[1]*0.9, 'Congressional ACH Appropriation Shutdown',
         rotation=90, verticalalignment='top', fontsize=9)

# US-Israeli Joint Strikes on Iran -- Feb 2026
evt_iran = pd.to_datetime('2026-02-28')
plt.axvline(x=evt_iran, color='gray', linestyle='--', linewidth=1)
plt.text(evt_iran, plt.ylim()[1]*0.9, 'IRGC Closes Strait of Hormuz',
         rotation=90, verticalalignment='top', fontsize=9)

# Formatting
#plt.title(f'US Inflation: Headline vs. Core CPI (June 2024 – {end.year})\nas of {str_current_date}', fontsize=14, fontweight='bold')
plt.title(f'US Inflation: Headline vs. Core CPI ({plot_start.strftime("%B %Y")} – {end.strftime("%B %Y")})\nas of {str_current_date}', fontsize=14, fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.axhline(0, color='black', linewidth=0.8, linestyle='-')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# /var/folders/71/ng2k1j0j5zl7wss17qgbmsfr0000gn/T/ipykernel_24804/3503538489.py:17: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_yoy = df.pct_change(periods=12) * 100
