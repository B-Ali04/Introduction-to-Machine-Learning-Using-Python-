# %% [markdown]
# # Global Crude Oil and Regional Gasoline in the U.S. (2024 – Present)
#
# ## Retail Gasoline Prices: Actual Prices & Year-over-Year Change
#
# ### Description
#
# This notebook provides a technical visualization of U.S. retail gasoline price trends. It utilizes data from the Federal Reserve Economic Data (FRED) to compare:
#
# - **Regular Grade:** Conventional Formulation (US Average)
# - **Regular Grade:** All Formulations (US Average)
# - **Unleaded Regular:** U.S. City Average
# - **All Formulations:** U.S. City Average
#
# The analysis tracks both actual weekly prices and year-over-year percentage changes to highlight gasoline price dynamics across formulation types and geographic aggregations.
#
# ---
#
# ## Objectives
#
# - Analyze retail gasoline price trends from 2024 to present day
# - Compare conventional vs. all-formulation pricing behaviors
# - Identify periods of price acceleration and deceleration
# - Provide a time-logged macroeconomic and energy market analysis
#
# ---
#
# ## Data Source
#
# - Federal Reserve Economic Data (FRED)
#   - `GASREGCOVW`: Regular Grade Conventional Gas Price, US Average (Weekly)
#   - `GASREGW`: Regular Grade Gas Price, All Formulations, US Average (Weekly)
#   - `APU000074714`: Average Price, Unleaded Regular, U.S. City Average
#   - `APU00007471A`: Average Price, Gasoline, All Formulations, U.S. City Average

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Install System Dependencies

# %%
# !pip install pandas-datareader
# Note: Uncomment below if necessary to ugrade installer
# !pip3 install --upgrade pip
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# ### Import Python Libraries

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### Define Global Functions

# %%
def add_event_lines(events, df_plot, y_position):
    """
    Plots vertical lines and labels for specific events within the date range of df_plot.
    
    Parameters:
    - events (dict): A dictionary of {'date_string': 'label'}.
    - df_plot (DataFrame): The pandas DataFrame being plotted (expects a DatetimeIndex).
    - y_position (float): The y-axis coordinate for the text labels.
    """
    for date_str, label in events.items():
        evt_date = pd.to_datetime(date_str)
        
        if df_plot.index.min() <= evt_date <= df_plot.index.max():
            plt.axvline(x=evt_date, 
                        color='black', 
                        linestyle=':', 
                        linewidth=1.2, 
                        alpha=0.7)
            
            plt.text(evt_date, y_position, label,
                     rotation=90, 
                     verticalalignment='top',
                     horizontalalignment='right',
                     fontsize=10,
                     fontweight='bold')
            
def add_event_lines_small(events, df_plot, y_position):
    """
    Plots vertical lines and labels for specific events within the date range of df_plot.
    
    Parameters:
    - events (dict): A dictionary of {'date_string': 'label'}.
    - df_plot (DataFrame): The pandas DataFrame being plotted (expects a DatetimeIndex).
    - y_position (float): The y-axis coordinate for the text labels.
    """
    for date_str, label in events.items():
        evt_date = pd.to_datetime(date_str)
        
        if df_plot.index.min() <= evt_date <= df_plot.index.max():
            plt.axvline(x=evt_date, 
                        color='black', 
                        linestyle=':', 
                        linewidth=1.2, 
                        alpha=0.7)
            
            plt.text(evt_date, y_position, label,
                     rotation=90, 
                     verticalalignment='top',
                     horizontalalignment='right',
                     fontsize=5,
                     fontweight='bold')

# %% [markdown]
# ### Standard Unit Initial Timeframe

# %%
start = datetime(2023, 4, 1)
end = datetime.now()
str_current_date = end.strftime("%B %d, %Y")
plot_start = start + relativedelta(weeks=52)

# %% [markdown]
# ## US Gasoline Trends (April 2024 -Present)
# ### Key Events
# - 2024 Presidential Election
# - 2025 Inaugurattion of Donald J. Trump
# - US Global Tariff Poliy enters effect
# - 2025 Government Shutdown
# - Iran War

# %%
gas_series = {
    'Regular, Conventional': {'id': 'GASREGCOVW', 'color': '#040404'},
    'Regular, All Formulations': {'id': 'GASREGW',    'color': '#e22222'},
    'Unleaded Regular, City Avg': {'id': 'APU000074714', 'color': '#05c10e'},
    'All Formulations, City Avg': {'id': 'APU00007471A', 'color': '#2e0cc3'}
}

events = [
    ('2024-11-04', '2024 Presidential Election'),
    ('2025-01-20', 'Donald Trump Enters Second Presidential Term'),
    ('2025-04-15', 'Trump Imposes Global Foreign Trade Policy'),
    ('2025-10-01', 'Congressional ACH Appropriation Shutdown'),
    ('2026-02-28', 'IRGC Closes Strait of Hormuz'),
]

raw_data = {}
transformed_data = {}

# %%
for label, meta in gas_series.items():
    df_raw = web.DataReader(meta['id'], 'fred', start, end)
    raw_data[label] = df_raw
    df_wow = (df_raw.pct_change(periods=52) * 100)
    transformed_data[label] = df_wow[df_wow.index >= plot_start]

r_date = transformed_data['Regular, Conventional'].index[-1]
r_val = transformed_data['Regular, Conventional'].iloc[-1, 0]
r_price = raw_data['Regular, Conventional'].iloc[-1, 0]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# Year-over-Year Percentage Change
# Note: Uncomment lines below to render all formulations on the YoY visualization
ax1.plot(transformed_data['Regular, Conventional'], label='Regular, Conventional', color=gas_series['Regular, Conventional']['color'], linewidth=2)
# ax1.plot(transformed_data['Regular, All Formulations'], label='Regular, All Formulations', color=gas_series['Regular, All Formulations']['color'], linewidth=2)
# ax1.plot(transformed_data['Unleaded Regular, City Avg'], label='Unleaded Regular, City Avg', color=gas_series['Unleaded Regular, City Avg']['color'], linewidth=2)
# ax1.plot(transformed_data['All Formulations, City Avg'], label='All Formulations, City Avg', color=gas_series['All Formulations, City Avg']['color'], linewidth=2)

ax1.set_ylabel('YoY % Change')
ax1.axhline(0, color='black', linewidth=0.8)

ax2.set_ylim(2, 6)
for label, df_raw in raw_data.items():
    ax2.plot(df_raw, label=label, color=gas_series[label]['color'], linewidth=2)
ax2.set_ylabel('Price (USD per Gallon)')

df_ref = list(raw_data.values())[0]

for ax in [ax1, ax2]:
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.legend(fontsize=8)
    
    y_pos = ax.get_ylim()[1] * 0.85
    for date_str, label in events:
        evt_date = pd.to_datetime(date_str)
        if df_ref.index.min() <= evt_date <= df_ref.index.max():
            ax.axvline(x=evt_date, 
                       color='black', 
                       linestyle=':', 
                       linewidth=1.2, 
                       alpha=0.7)
            ax.text(evt_date, 
                    y_pos, 
                    label, 
                    rotation=90, 
                    verticalalignment='top', 
                    horizontalalignment='right', 
                    fontsize=5, 
                    fontweight='bold')

ax1.tick_params(axis='x', labelbottom=True)
ax1.set_xlabel('Year')
ax2.set_xlabel('Year')

ax1.annotate(f"${r_price:.2f} ({r_val:.1f}%) - {r_date.strftime('%b %d %Y')}", 
             xy=(r_date, r_val), 
             textcoords="offset points", 
             xytext=(-45, -40), 
             ha='center', 
             weight='bold', 
             color='black',
             bbox=dict(boxstyle='round,pad=0.2', fc='white', alpha=0.8, ec='none'))

ax1.axhline(y=r_val, 
            color="#000000", 
            linestyle=':', 
            linewidth=1.5, 
            alpha=0.8)

ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=4)) 
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y')) 

ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=4)) 
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y')) 
plt.xticks(rotation=45)

fig.suptitle(f'US Gas Prices: YoY Change & Actual Prices\n({plot_start.strftime("%B %Y")} – {end.strftime("%B %Y")})  |  as of {str_current_date}',
             fontsize=14, 
             fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/71/ng2k1j0j5zl7wss17qgbmsfr0000gn/T/ipykernel_12486/1594246625.py:4: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_wow = (df_raw.pct_change(periods=52) * 100)

# %% [markdown]
# # Brent Crude Oil and WTI Crude Oil

# %%
start = datetime(2024, 4, 1)
end = datetime.now()
plot_start = '2023-04-01'

crude_series = {
    'Brent Crude (Europe)': {'id': 'WCOILBRENTEU', 'color': '#ff7f0e'},
    'WTI Crude (Cushing)': {'id': 'WCOILWTICO', 'color': '#9467bd'}
}

raw_data = {}
for label, meta in crude_series.items():
    df = web.DataReader(meta['id'], 'fred', start, end)
    raw_data[label] = df[meta['id']]

df_crude = pd.DataFrame(raw_data)
df_plot = df_crude.loc[plot_start:]

fig, ax = plt.subplots(figsize=(12, 6))

for label, meta in crude_series.items():
    series = df_plot[label].dropna()
    ax.plot(series.index, series, label=label, color=meta['color'], linewidth=2.0)
    
    peak_dt, peak_val = series.idxmax(), series.max()
    trough_dt, trough_val = series.idxmin(), series.min()
    latest_dt, latest_val = series.index[-1], series.iloc[-1]
    
    is_brent = 'Brent' in label
    
    peak_xytext = (0, 25) if is_brent else (0, -35)
    trough_xytext = (0, -35) if is_brent else (0, -55)
    
    ax.annotate(
        f'{label.split()[0]} Peak: ${peak_val:.2f}\n({peak_dt.strftime("%b %d, %Y")})',
        xy=(peak_dt, peak_val),
        xytext=peak_xytext,
        textcoords='offset points',
        ha='center',
        arrowprops=dict(arrowstyle='->', color=meta['color'], lw=1.2),
        fontsize=8.5,
        fontweight='bold',
        color=meta['color'],
        bbox=dict(boxstyle='round,pad=0.25', facecolor='white', edgecolor=meta['color'], alpha=0.85)
    )
    
    ax.annotate(
        f'{label.split()[0]} Trough: ${trough_val:.2f}\n({trough_dt.strftime("%b %d, %Y")})',
        xy=(trough_dt, trough_val),
        xytext=trough_xytext,
        textcoords='offset points',
        ha='center',
        arrowprops=dict(arrowstyle='->', color=meta['color'], lw=1.2),
        fontsize=8.5,
        fontweight='bold',
        color=meta['color'],
        bbox=dict(boxstyle='round,pad=0.25', facecolor='white', edgecolor=meta['color'], alpha=0.85)
    )
    
    ax.annotate(
        f' Latest: ${latest_val:.2f}',
        xy=(latest_dt, latest_val),
        xytext=(6, 0),
        textcoords='offset points',
        va='center',
        fontsize=9,
        fontweight='bold',
        color=meta['color']
    )

ax.set_xlim(right=df_plot.index[-1] + pd.Timedelta(days=35))  # Padding for latest labels
ax.set_ylabel('Price ($/Barrel)', fontsize=11, fontweight='bold')
ax.set_title('Crude Oil Benchmarks: Brent vs. WTI Spot Prices', fontsize=14, fontweight='bold', pad=15)

ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.xticks(rotation=45)

ax.legend(loc='upper left', frameon=True, facecolor='white', framealpha=0.9)
ax.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusions and Observations

# %% [markdown]
# ### Fuel and Energy – 31 July 2026
#
# #### If you could go back in time...
#
# I'm putting things very bluntly for this report.
#
# Gas prices are on the rise again, while stock markets are moving fearfully in the United States.
#
# As of July 28, 2026, FRED reports conventional oil is pricing at **$3.95 per gallon.**
#
# Data continues to show:
#
# - All formulations pricing at **$4.10 per gallon** as of July 28, 2026.
# - City average for unleaded gasoline pricing at **$4.20 per gallon** in the month of June.
# - City average for all formulatoins pricing at **$4.35 per gallon** in the month of June.
#
# ##### State of Global Markets
#
# Brent crude oil started at **$89.38 per barrel** as of July 31, 2026, after closing at **$89.03 per barrel** the previous day.
#
# WTI crude oil started at **$83.92 per barrel** as of July 31, 2026, after closing at **$83.59 per barrel** the previous day.
#
# Futures are subject to the same range, just over $82 per barrel for each individual category.
#
# Many consider the current behavior of the markets to be reflective of surge pricing.
#
# I call it trying to pacifiy a baby in a stinky diaper.
#
# ##### The Good/Bad News
#
# The United States of America brokered a deal with Saudi Arabia regarding constructing civilian nuclear energy infrastructre. Good.
#
# After signing, the United States added the clause that the deal would only become effeective if Saudi Arabia joined the Abraham Accords. Bad.
#
# Iraq and Syria have agreed to a reconstruction plan regarding the Kirkuk-Baniyas oil pipeline in a deal backed by the United States. Good.
#
# The United States and Saudi Arabia atacked Iranian backed militia in Iraq, reportedly killing 6 Iraqi advisors in the attack. Bad.
#
# Ukraine attacked several Iranian ships in the Caspain Sea, carrying military supplies to Russia. "Bad."
#
# Hamas has conditionally agreed to completely disarm, upon Israel keeping their promise, and the IDF will withdraw from Gaza. "Good"
#
# ##### Closing
#
# Whomever is going about life as if "this is perfect" should be checked up on by a liscensed therapist. Things are <u>NOT</u> perfect.
#
# Ignoring it, pretending it doesn't affect you, "keeping yourself busy," is a distraction from what is really happening.
#
# Prices are already rising because diesel prices are extremely high. Real GDP growth last quarter slowed to **1.5% down from 2.1%** in Q1.
#
# Life in 2026 should be improving, but as oil burnoff hit record lows in recent months, economic growth is a child's tea party, and the search for non-existent weapons continues...
#
# Hummanity is due ofor a miracle, or perhaps, a worldwide cannon event that forces many of us to read their own history, and make a plan that moves forward.
#
# ___
#
# **Thank you for reading. I'm going to upload analysis when there are significant changes to be made regarding econonmic performance metrics.**
#
# **Currently, the United State's War in Iran has begun it's bleeding into other countries in the Middle East.**
#
# **Awkwardly, Russia and Ukraine have also gotten involved while China, NATO, and all of Europe try to stay out of it.**
#
# **Similarly, I'm going to be writing a lot less from my perspective and just put the numbers on the screen.**
#
# **The math speaks for itself, if you don't like the numbers, cry about it. See if you like it better when you're done.**
#
# ***Until the next one.***
#
# ___
#
# ___

# %% [markdown]
# #### Update Schedule
#
# - ***U.S. Regular - Aug 4, 2026***
#
#     1. `GASREGCOVW`: **Conventional (Weekly)**
#     2. `GASREGW`: **All Formulations (Weekly)**
#
# - ***U.S. City Average - Aug 12, 2026***
#
#     3. `APU000074714`: **Unleaded Regular**
#     4. `APU00007471A`: **All Formulations**

# %% [markdown]
# #### Data Changelog / Notes
